# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use("ggplot")
sns.set_style("darkgrid")
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("weed_clean.csv")

# %%
df.shape
# Out:
# (51, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              51 non-null     object
#  1   state_s            51 non-null     object
#  2   highQ_price_ounce  51 non-null     int64
#  3   medQ_price_ounce   51 non-null     int64
#  4   total_population   51 non-null     int64
#  5   percent_white      51 non-null     int64
#  6   percent_black      51 non-null     int64
#  7   percent_asian      51 non-null     int64
#  8   percent_hispanic   51 non-null     int64
#  9   per_capita_income  51 non-null     int64
#  10  median_rent        51 non-null     int64
#  11  median_age         51 non-null     float64
# dtypes: float64(1), int64(9), object(2)
# memory usage: 4.9+ KB

# %%
df.columns
# Out:
# Index(['state', 'state_s', 'highQ_price_ounce', 'medQ_price_ounce',
#        'total_population', 'percent_white', 'percent_black', 'percent_asian',
#        'percent_hispanic', 'per_capita_income', 'median_rent', 'median_age'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# state                0
# state_s              0
# highQ_price_ounce    0
# medQ_price_ounce     0
# total_population     0
# percent_white        0
# percent_black        0
# percent_asian        0
# percent_hispanic     0
# per_capita_income    0
# median_rent          0
# median_age           0
# dtype: int64

# %%
df.head()
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 0     Alabama      AL                341               230           4799277
# 1      Alaska      AK                303               270            720316
# 2     Arizona      AZ                296               232           6479703
# 3    Arkansas      AR                329               240           2933369
# 4  California      CA                258               209          37659181
#
#    percent_white  percent_black  percent_asian  percent_hispanic  \
# 0             67             26              1                 4
# 1             63              3              5                 6
# 2             57              4              3                30
# 3             74             15              1                 7
# 4             40              6             13                38
#
#    per_capita_income  median_rent  median_age
# 0              23680          501        38.1
# 1              32651          978        33.6
# 2              25358          747        36.3
# 3              22170          480        37.5
# 4              29527         1119        35.4

# %%
df[df["state"] == "California"]
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 4  California      CA                258               209          37659181
#
#    percent_white  percent_black  percent_asian  percent_hispanic  \
# 4             40              6             13                38
#
#    per_capita_income  median_rent  median_age
# 4              29527         1119        35.4

# %%
df[df["state"] == "California"].plot(kind="bar", y=["highQ_price_ounce", "medQ_price_ounce"], title="California Weed Prices top_self vs mid_tear")
# Out:
# <Axes: title={'center': 'California Weed Prices top_self vs mid_tear'}>

# %%
df[df["state"] == "California"].plot(kind="bar",\
                                     y=["percent_white","percent_black","percent_asian","percent_hispanic"], \
                                     title="California Weed consumption by Race")
# Out:
# <Axes: title={'center': 'California Weed consumption by Race'}>

# %%
df.sample()
# Out:
#       state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 7  Delaware      DE                339               261            908446
#
#    percent_white  percent_black  percent_asian  percent_hispanic  \
# 7             65             21              3                 8
#
#    per_capita_income  median_rent  median_age
# 7              29819          828        38.9

# %%
state_with_highq_high_price = df.sort_values("highQ_price_ounce", ascending=False).head(1)["state"]

# %%
print(f"The price of weed with high quality is highest in {state_with_highq_high_price.iloc[0]}")
# Out:
# The price of weed with high quality is highest in District of Columbia

# %%
state_with_medq_high_price = df.sort_values("medQ_price_ounce", ascending=False).head(1)['state']

# %%
print(f"The price of weed with medium quality is highest in {state_with_medq_high_price.iloc[0]}")
# Out:
# The price of weed with medium quality is highest in South Dakota

# %%
state_with_highq_lowest_price = df.sort_values("highQ_price_ounce").head(1)['state']

# %%
print(f"The price of weed with high quality is lowest in {state_with_highq_lowest_price.iloc[0]}")
# Out:
# The price of weed with high quality is lowest in Oregon

# %%
state_with_medq_lowest_price = df.sort_values("medQ_price_ounce").head(1)['state']

# %%
print(f"The price of weed with medium quality is lowest in {state_with_medq_lowest_price.iloc[0]}")
# Out:
# The price of weed with medium quality is lowest in Mississippi

# %%
df.head()
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 0     Alabama      AL                341               230           4799277
# 1      Alaska      AK                303               270            720316
# 2     Arizona      AZ                296               232           6479703
# 3    Arkansas      AR                329               240           2933369
# 4  California      CA                258               209          37659181
#
#    percent_white  percent_black  percent_asian  percent_hispanic  \
# 0             67             26              1                 4
# 1             63              3              5                 6
# 2             57              4              3                30
# 3             74             15              1                 7
# 4             40              6             13                38
#
#    per_capita_income  median_rent  median_age
# 0              23680          501        38.1
# 1              32651          978        33.6
# 2              25358          747        36.3
# 3              22170          480        37.5
# 4              29527         1119        35.4

# %%
df.loc[df["median_rent"] < 500].plot(kind="bar", x="state_s", y =["highQ_price_ounce", "medQ_price_ounce" ] )
# Out:
# <Axes: xlabel='state_s'>

# %%
df.loc[df["median_rent"] > 1000]
# Out:
#                    state state_s  highQ_price_ounce  medQ_price_ounce  \
# 4             California      CA                258               209
# 8   District of Columbia      DC                528               325
# 11                Hawaii      HI                314               268
# 20              Maryland      MD                359               283
# 30            New Jersey      NJ                341               297
#
#     total_population  percent_white  percent_black  percent_asian  \
# 4           37659181             40              6             13
# 8             619371             35             49              3
# 11           1376298             23              2             37
# 20           5834299             54             29              6
# 30           8832406             59             13              9
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 4                 38              29527         1119        35.4
# 8                 10              45290         1154        33.8
# 11                 9              29305         1220        38.3
# 20                 8              36354         1034        38.0
# 30                18              36027         1024        39.1

# %%
df.loc[df["median_rent"] > 1000].plot(kind="barh", figsize=(10, 5), x="state_s", y=["median_rent", "highQ_price_ounce", "medQ_price_ounce"])
# Out:
# <Axes: ylabel='state_s'>

# %%
df.head()
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 0     Alabama      AL                341               230           4799277
# 1      Alaska      AK                303               270            720316
# 2     Arizona      AZ                296               232           6479703
# 3    Arkansas      AR                329               240           2933369
# 4  California      CA                258               209          37659181
#
#    percent_white  percent_black  percent_asian  percent_hispanic  \
# 0             67             26              1                 4
# 1             63              3              5                 6
# 2             57              4              3                30
# 3             74             15              1                 7
# 4             40              6             13                38
#
#    per_capita_income  median_rent  median_age
# 0              23680          501        38.1
# 1              32651          978        33.6
# 2              25358          747        36.3
# 3              22170          480        37.5
# 4              29527         1119        35.4

# %%
df.sort_values("per_capita_income").head(10)
# Out:
#              state state_s  highQ_price_ounce  medQ_price_ounce  \
# 24     Mississippi      MS                347               172
# 3         Arkansas      AR                329               240
# 12           Idaho      ID                273               244
# 48   West Virginia      WV                361               255
# 17        Kentucky      KY                336               228
# 0          Alabama      AL                341               230
# 31      New Mexico      NM                283               228
# 44            Utah      UT                280               244
# 40  South Carolina      SC                334               230
# 36        Oklahoma      OK                341               265
#
#     total_population  percent_white  percent_black  percent_asian  \
# 24           2976872             58             37              1
# 3            2933369             74             15              1
# 12           1583364             84              1              1
# 48           1853619             93              3              1
# 17           4361333             86              8              1
# 0            4799277             67             26              1
# 31           2069706             40              2              1
# 44           2813673             80              1              2
# 40           4679602             64             28              1
# 36           3785742             68              7              2
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 24                 3              20618          510        36.2
# 3                  7              22170          480        37.5
# 12                11              22568          607        34.9
# 48                 1              22966          448        41.5
# 17                 3              23462          506        38.2
# 0                  4              23680          501        38.1
# 31                47              23763          635        36.7
# 44                13              23873          739        29.6
# 40                 5              23943          582        38.1
# 36                 9              24208          525        36.2

# %%
df.sort_values("per_capita_income").head(10).plot(kind="bar", x="state_s", y="per_capita_income", title="Bottom 10 states by per capita income")
# Out:
# <Axes: title={'center': 'Bottom 10 states by per capita income'}, xlabel='state_s'>

# %%
df.sort_values("per_capita_income", ascending=False).head(10)\
.plot(kind="bar", figsize=(10, 5), x="state_s", y="per_capita_income", title="Top 10 states by per capita income")
# Out:
# <Axes: title={'center': 'Top 10 states by per capita income'}, xlabel='state_s'>

# %%
df.sample(2)
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 45    Vermont      VT                341               298            625904
# 42  Tennessee      TN                343               260           6402387
#
#     percent_white  percent_black  percent_asian  percent_hispanic  \
# 45             94              1              1                 2
# 42             75             17              1                 5
#
#     per_capita_income  median_rent  median_age
# 45              29167          754        42.0
# 42              24409          568        38.2

# %%
df.sort_values("total_population").head(10)
# Out:
#                    state state_s  highQ_price_ounce  medQ_price_ounce  \
# 50               Wyoming      WY                315               320
# 8   District of Columbia      DC                528               325
# 45               Vermont      VT                341               298
# 34          North Dakota      ND                382               326
# 1                 Alaska      AK                303               270
# 41          South Dakota      SD                350               336
# 7               Delaware      DE                339               261
# 26               Montana      MT                266               245
# 39          Rhode Island      RI                306               255
# 29         New Hampshire      NH                331               278
#
#     total_population  percent_white  percent_black  percent_asian  \
# 50            570134             85              1              1
# 8             619371             35             49              3
# 45            625904             94              1              1
# 34            689781             88              1              1
# 1             720316             63              3              5
# 41            825198             84              1              1
# 7             908446             65             21              3
# 26            998554             87              0              1
# 39           1051695             76              5              3
# 29           1319171             92              1              2
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 50                 9              28902          647        36.8
# 8                 10              45290         1154        33.8
# 45                 2              29167          754        42.0
# 34                 2              29732          564        36.4
# 1                  6              32651          978        33.6
# 41                 3              25740          517        36.9
# 7                  8              29819          828        38.9
# 26                 3              25373          577        39.9
# 39                13              30469          781        39.6
# 29                 3              33134          878        41.5

# %%
df.sort_values("total_population").head(10).plot(kind="bar", x="state_s", y="total_population", title="Bottom 10 states by total population")
# Out:
# <Axes: title={'center': 'Bottom 10 states by total population'}, xlabel='state_s'>

# %%
df.sort_values("total_population", ascending=False).head(10)\
.plot(kind="bar", figsize=(10, 5), x="state_s", y="total_population", title="Top 10 states by total population")
# Out:
# <Axes: title={'center': 'Top 10 states by total population'}, xlabel='state_s'>

# %%
df.sample(2)
# Out:
#      state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 16  Kansas      KS                341               285           2868107
# 37  Oregon      OR                210               186           3868721
#
#     percent_white  percent_black  percent_asian  percent_hispanic  \
# 16             78              6              2                11
# 37             78              2              4                12
#
#     per_capita_income  median_rent  median_age
# 16              26929          551        36.0
# 37              26809          749        38.7

# %%
df.sort_values("median_age").head(10)
# Out:
#                    state state_s  highQ_price_ounce  medQ_price_ounce  \
# 44                  Utah      UT                280               244
# 1                 Alaska      AK                303               270
# 8   District of Columbia      DC                528               325
# 43                 Texas      TX                323               249
# 12                 Idaho      ID                273               244
# 4             California      CA                258               209
# 10               Georgia      GA                317               235
# 18             Louisiana      LA                356               258
# 16                Kansas      KS                341               285
# 5               Colorado      CO                242               200
#
#     total_population  percent_white  percent_black  percent_asian  \
# 44           2813673             80              1              2
# 1             720316             63              3              5
# 8             619371             35             49              3
# 43          25639373             45             12              4
# 12           1583364             84              1              1
# 4           37659181             40              6             13
# 10           9810417             55             30              3
# 18           4567968             60             32              2
# 16           2868107             78              6              2
# 5            5119329             70              4              3
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 44                13              23873          739        29.6
# 1                  6              32651          978        33.6
# 8                 10              45290         1154        33.8
# 43                38              26019          688        33.8
# 12                11              22568          607        34.9
# 4                 38              29527         1119        35.4
# 10                 9              25182          673        35.6
# 18                 4              24442          610        36.0
# 16                11              26929          551        36.0
# 5                 21              31109          825        36.1

# %%
df.sort_values("median_age").head(10).plot(kind="bar", x="state_s", y="median_age", title="Top 10 states by median age")
# Out:
# <Axes: title={'center': 'Top 10 states by median age'}, xlabel='state_s'>

# %%
df.sort_values("median_age", ascending=False).head(10).plot(kind="bar", figsize=(10, 5), x="state_s", y="median_age", title="Top 10 states by median age")
# Out:
# <Axes: title={'center': 'Top 10 states by median age'}, xlabel='state_s'>

# %%
df.sample(2)
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 18  Louisiana      LA                356               258           4567968
# 36   Oklahoma      OK                341               265           3785742
#
#     percent_white  percent_black  percent_asian  percent_hispanic  \
# 18             60             32              2                 4
# 36             68              7              2                 9
#
#     per_capita_income  median_rent  median_age
# 18              24442          610        36.0
# 36              24208          525        36.2

# %%
df[df["medQ_price_ounce"] < 200]
# Out:
#           state state_s  highQ_price_ounce  medQ_price_ounce  \
# 24  Mississippi      MS                347               172
# 37       Oregon      OR                210               186
# 47   Washington      WA                233               197
#
#     total_population  percent_white  percent_black  percent_asian  \
# 24           2976872             58             37              1
# 37           3868721             78              2              4
# 47           6819579             72              3              7
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 24                 3              20618          510        36.2
# 37                12              26809          749        38.7
# 47                11              30742          853        37.3

# %%
df[df["medQ_price_ounce"] < 200].plot(kind="bar", x="state_s", y=["highQ_price_ounce", "medQ_price_ounce"], \
                                      figsize=(10,5), title="Weed Prices by State where medium quality is less than $200")
# Out:
# <Axes: title={'center': 'Weed Prices by State where medium quality is less than $200'}, xlabel='state_s'>

# %%
df.loc[df["per_capita_income"] < 25000]
# Out:
#              state state_s  highQ_price_ounce  medQ_price_ounce  \
# 0          Alabama      AL                341               230
# 3         Arkansas      AR                329               240
# 12           Idaho      ID                273               244
# 14         Indiana      IN                330               236
# 17        Kentucky      KY                336               228
# 18       Louisiana      LA                356               258
# 24     Mississippi      MS                347               172
# 31      New Mexico      NM                283               228
# 36        Oklahoma      OK                341               265
# 40  South Carolina      SC                334               230
# 42       Tennessee      TN                343               260
# 44            Utah      UT                280               244
# 48   West Virginia      WV                361               255
#
#     total_population  percent_white  percent_black  percent_asian  \
# 0            4799277             67             26              1
# 3            2933369             74             15              1
# 12           1583364             84              1              1
# 14           6514861             81              9              2
# 17           4361333             86              8              1
# 18           4567968             60             32              2
# 24           2976872             58             37              1
# 31           2069706             40              2              1
# 36           3785742             68              7              2
# 40           4679602             64             28              1
# 42           6402387             75             17              1
# 44           2813673             80              1              2
# 48           1853619             93              3              1
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 0                  4              23680          501        38.1
# 3                  7              22170          480        37.5
# 12                11              22568          607        34.9
# 14                 6              24635          577        37.1
# 17                 3              23462          506        38.2
# 18                 4              24442          610        36.0
# 24                 3              20618          510        36.2
# 31                47              23763          635        36.7
# 36                 9              24208          525        36.2
# 40                 5              23943          582        38.1
# 42                 5              24409          568        38.2
# 44                13              23873          739        29.6
# 48                 1              22966          448        41.5

# %%
df.loc[df["per_capita_income"] < 25000].plot(kind="bar", figsize=(10, 5), x="state_s", y="per_capita_income", title="States with less than $25000 per capita income")
# Out:
# <Axes: title={'center': 'States with less than $25000 per capita income'}, xlabel='state_s'>

# %%
df.sample(2)
# Out:
#          state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 35        Ohio      OH                328               235          11549590
# 4   California      CA                258               209          37659181
#
#     percent_white  percent_black  percent_asian  percent_hispanic  \
# 35             81             12              2                 3
# 4              40              6             13                38
#
#     per_capita_income  median_rent  median_age
# 35              26046          562        39.0
# 4               29527         1119        35.4

# %%
# find states with highest population and highest per_capita_income, compare the price in those states
df.loc[df["total_population"] == df["total_population"].max()]
# Out:
#         state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 4  California      CA                258               209          37659181
#
#    percent_white  percent_black  percent_asian  percent_hispanic  \
# 4             40              6             13                38
#
#    per_capita_income  median_rent  median_age
# 4              29527         1119        35.4

# %%
df.loc[df["per_capita_income"] == df["per_capita_income"].max()]
# Out:
#                   state state_s  highQ_price_ounce  medQ_price_ounce  \
# 8  District of Columbia      DC                528               325
#
#    total_population  percent_white  percent_black  percent_asian  \
# 8            619371             35             49              3
#
#    percent_hispanic  per_capita_income  median_rent  median_age
# 8                10              45290         1154        33.8

# %%
df.loc[(df["total_population"] > 10000000) & (df["per_capita_income"] > 25000)]
# Out:
#            state state_s  highQ_price_ounce  medQ_price_ounce  \
# 4     California      CA                258               209
# 9        Florida      FL                299               229
# 13      Illinois      IL                351               296
# 32      New York      NY                336               269
# 35          Ohio      OH                328               235
# 38  Pennsylvania      PA                355               286
# 43         Texas      TX                323               249
#
#     total_population  percent_white  percent_black  percent_asian  \
# 4           37659181             40              6             13
# 9           19091156             57             15              2
# 13          12848554             63             14              5
# 32          19487053             58             14              8
# 35          11549590             81             12              2
# 38          12731381             79             10              3
# 43          25639373             45             12              4
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 4                 38              29527         1119        35.4
# 9                 23              26236          838        41.0
# 13                16              29666          759        36.8
# 32                18              32382          963        38.1
# 35                 3              26046          562        39.0
# 38                 6              28502          652        40.3
# 43                38              26019          688        33.8

# %%
df.loc[(df["total_population"] > 10000000) & (df["per_capita_income"] > 25000)].plot\
(kind="bar", figsize=(10, 5), x="state_s", y="total_population",ylabel="population", title="High population state with more than $25000 of median income")
# Out:
# <Axes: title={'center': 'High population state with more than $25000 of median income'}, xlabel='state_s', ylabel='population'>

# %%
df.sample(2)
# Out:
#             state state_s  highQ_price_ounce  medQ_price_ounce  \
# 29  New Hampshire      NH                331               278
# 11         Hawaii      HI                314               268
#
#     total_population  percent_white  percent_black  percent_asian  \
# 29           1319171             92              1              2
# 11           1376298             23              2             37
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 29                 3              33134          878        41.5
# 11                 9              29305         1220        38.3

# %%
df.sort_values("highQ_price_ounce", ascending=False).head(10)
# Out:
#                    state state_s  highQ_price_ounce  medQ_price_ounce  \
# 8   District of Columbia      DC                528               325
# 34          North Dakota      ND                382               326
# 15                  Iowa      IA                363               307
# 46              Virginia      VA                363               288
# 48         West Virginia      WV                361               255
# 20              Maryland      MD                359               283
# 18             Louisiana      LA                356               258
# 38          Pennsylvania      PA                355               286
# 25              Missouri      MO                352               273
# 13              Illinois      IL                351               296
#
#     total_population  percent_white  percent_black  percent_asian  \
# 8             619371             35             49              3
# 34            689781             88              1              1
# 15           3062553             88              3              2
# 46           8100653             64             19              6
# 48           1853619             93              3              1
# 20           5834299             54             29              6
# 18           4567968             60             32              2
# 38          12731381             79             10              3
# 25           6007182             81             11              2
# 13          12848554             63             14              5
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 8                 10              45290         1154        33.8
# 34                 2              29732          564        36.4
# 15                 5              27027          534        38.1
# 46                 8              33493          910        37.5
# 48                 1              22966          448        41.5
# 20                 8              36354         1034        38.0
# 18                 4              24442          610        36.0
# 38                 6              28502          652        40.3
# 25                 4              25649          549        38.0
# 13                16              29666          759        36.8

# %%
df.sort_values("highQ_price_ounce", ascending=False).head(10).plot(kind="bar", x="state_s", y="highQ_price_ounce")
# Out:
# <Axes: xlabel='state_s'>

# %%
df.sort_values("highQ_price_ounce").head(10).plot(kind="bar", x="state_s", y="highQ_price_ounce")
# Out:
# <Axes: xlabel='state_s'>

# %%
df.sample(2)
# Out:
#          state state_s  highQ_price_ounce  medQ_price_ounce  total_population  \
# 31  New Mexico      NM                283               228           2069706
# 5     Colorado      CO                242               200           5119329
#
#     percent_white  percent_black  percent_asian  percent_hispanic  \
# 31             40              2              1                47
# 5              70              4              3                21
#
#     per_capita_income  median_rent  median_age
# 31              23763          635        36.7
# 5               31109          825        36.1

# %%
df.sort_values("percent_white", ascending=False).head(3)
# Out:
#             state state_s  highQ_price_ounce  medQ_price_ounce  \
# 45        Vermont      VT                341               298
# 19          Maine      ME                286               230
# 48  West Virginia      WV                361               255
#
#     total_population  percent_white  percent_black  percent_asian  \
# 45            625904             94              1              1
# 19           1328320             94              1              1
# 48           1853619             93              3              1
#
#     percent_hispanic  per_capita_income  median_rent  median_age
# 45                 2              29167          754        42.0
# 19                 1              26824          664        43.2
# 48                 1              22966          448        41.5

# %%
df.sort_values("percent_white", ascending=False).head(10).plot(kind="bar", x="state_s", \
                                                               y=["percent_white", "percent_black", "percent_asian","percent_hispanic"],\
                                                               log=True, figsize=(12, 5), title="Top 10 states by highest percent white population")
# Out:
# <Axes: title={'center': 'Top 10 states by highest percent white population'}, xlabel='state_s'>

# %%
df.sort_values("percent_black", ascending=False).head(10).plot(kind="bar", x="state_s", \
                                                               y=[ "percent_black","percent_white", "percent_asian","percent_hispanic"],\
                                                               log=True, figsize=(12, 5), title="Top 10 states by highest percent black population")
# Out:
# <Axes: title={'center': 'Top 10 states by highest percent black population'}, xlabel='state_s'>

# %%
df.sort_values("percent_asian", ascending=False).head(10).plot(kind="bar", x="state_s", \
                                                               y=[ "percent_black","percent_white", "percent_asian","percent_hispanic"],\
                                                               log=True, figsize=(12, 5), title="Top 10 states by highest percent asian population")
# Out:
# <Axes: title={'center': 'Top 10 states by highest percent asian population'}, xlabel='state_s'>

# %%
df.sort_values("percent_hispanic", ascending=False).head(10).plot(kind="bar", x="state_s", \
                                                               y=[ "percent_black","percent_white", "percent_asian","percent_hispanic"],\
                                                               log=True, figsize=(12, 5), title="Top 10 states by highest percent hispanic population")
# Out:
# <Axes: title={'center': 'Top 10 states by highest percent hispanic population'}, xlabel='state_s'>

# %%
correlation_matrix = df.corr(numeric_only=True)

# %%
# heatmap for correlation_matrix
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlation_matrix, annot=True, linewidths=0.5, fmt=".2f", cmap="YlGnBu")

# %%
# pair plot
sns.pairplot(df)
plt.show()
