# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("inflation-consumer.csv")

# %%
df.shape
# Out:
# (11014, 4)

# %%
df.head()
# Out:
#       Country Country Code  Year  Inflation
# 0  Arab World          ARB  1969   1.303790
# 1  Arab World          ARB  1970   2.602241
# 2  Arab World          ARB  1971   6.884719
# 3  Arab World          ARB  1972   2.496081
# 4  Arab World          ARB  1973  11.555281

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11014 entries, 0 to 11013
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       11014 non-null  object
#  1   Country Code  11014 non-null  object
#  2   Year          11014 non-null  int64
#  3   Inflation     11014 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 344.3+ KB

# %%
# change df['Year'] to date format
df['Year'] = pd.to_datetime(df['Year']).dt.year

# %%
df.shape
# Out:
# (11014, 4)

# %%
df.sort_values("Inflation")
# Out:
#                 Country Country Code  Year     Inflation
# 5868          Indonesia          IDN  1970    -98.703831
# 3313  Brunei Darussalam          BRN  1970    -31.904748
# 4697  Equatorial Guinea          GNQ  1970    -31.565915
# 4099        Congo, Rep.          COG  1970    -29.691067
# 4070        Congo, Rep.          COG  1970    -29.172662
# ...                 ...          ...   ...           ...
# 8561               Peru          PER  1970   6261.239559
# 3136            Bolivia          BOL  1970  12338.661610
# 8022          Nicaragua          NIC  1970  13611.634819
# 5127            Georgia          GEO  1970  15444.384137
# 4022   Congo, Dem. Rep.          COD  1970  26762.018330
#
# [11014 rows x 4 columns]

# %%
df.sort_values("Inflation", ascending=False).head(10).plot(kind="bar", x="Country", y="Inflation", title="Top 10 Countries with Highest Inflation")
# Out:
# <Axes: title={'center': 'Top 10 Countries with Highest Inflation'}, xlabel='Country'>

# %%
df.sort_values("Inflation").head(10).plot(kind="bar", x="Country", y="Inflation", title="Top 10 Countries with Highest Deflation")
# Out:
# <Axes: title={'center': 'Top 10 Countries with Highest Deflation'}, xlabel='Country'>

# %%
df.sample(2)
# Out:
#                Country Country Code  Year  Inflation
# 4579  Egypt, Arab Rep.          EGY  1970   1.350404
# 6593            Kuwait          KWT  1970   4.924563

# %%
df.groupby("Country")["Year"].count()
# Out:
# Country
# Afghanistan           14
# Albania               36
# Algeria               56
# American Samoa        14
# Andorra               46
#                       ..
# West Bank and Gaza    22
# World                 48
# Yemen, Rep.           26
# Zambia                56
# Zimbabwe              56
# Name: Year, Length: 255, dtype: int64

# %%
df["Year"].value_counts()
# Out:
# Year
# 1970    11014
# Name: count, dtype: int64

# %%
df["Country"].value_counts().head(20)
# Out:
# Country
# Zimbabwe        56
# Cameroon        56
# Japan           56
# Burundi         56
# Burkina Faso    56
# Kenya           56
# Korea, Rep.     56
# Brazil          56
# Botswana        56
# Lesotho         56
# Bolivia         56
# Liberia         56
# Luxembourg      56
# Benin           56
# Belize          56
# Belgium         56
# Madagascar      56
# Malawi          56
# Bangladesh      56
# Malaysia        56
# Name: count, dtype: int64

# %%
df[df["Country"] == "Nepal"]
# Out:
#      Country Country Code  Year  Inflation
# 7809   Nepal          NPL  1970   2.688000
# 7810   Nepal          NPL  1970   5.897091
# 7811   Nepal          NPL  1970   3.569925
# 7812   Nepal          NPL  1970   1.194720
# 7813   Nepal          NPL  1970  12.885194
# 7814   Nepal          NPL  1970  15.218814
# 7815   Nepal          NPL  1970  -5.667665
# 7816   Nepal          NPL  1970  11.065826
# 7817   Nepal          NPL  1970   6.563831
# 7818   Nepal          NPL  1970   7.048331
# 7819   Nepal          NPL  1970   3.172176
# 7820   Nepal          NPL  1970  12.502683
# 7821   Nepal          NPL  1970  -3.397306
# 7822   Nepal          NPL  1970  20.825670
# 7823   Nepal          NPL  1970  27.522747
# 7824   Nepal          NPL  1970   0.544042
# 7825   Nepal          NPL  1970  -3.564822
# 7826   Nepal          NPL  1970   9.371207
# 7827   Nepal          NPL  1970   9.978363
# 7828   Nepal          NPL  1970   7.609547
# 7829   Nepal          NPL  1970   7.937356
# ...

# %%
df[df["Country"] == "Nepal"].shape[0]
# Out:
# 56

# %%
min_inflation = df[df["Country"] == "Nepal"].min()["Inflation"]
max_inflation = df[df["Country"] == "Nepal"].max()["Inflation"]

# %%
pd.Series([min_inflation, max_inflation]).plot(kind="bar", title="Nepal's Inflation Range in 1970")
# Out:
# <Axes: title={'center': "Nepal's Inflation Range in 1970"}>

# %%
correlation_matrix = df.corr(numeric_only=True)

# %%
correlation_matrix
# Out:
#            Year  Inflation
# Year        NaN        NaN
# Inflation   NaN        1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11014 entries, 0 to 11013
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       11014 non-null  object
#  1   Country Code  11014 non-null  object
#  2   Year          11014 non-null  int32
#  3   Inflation     11014 non-null  float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 301.3+ KB

# %%
# pairplot
sns.pairplot(df)
plt.show()
