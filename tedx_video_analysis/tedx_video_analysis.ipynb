# %%
import pandas as pd

# %%
df = pd.read_csv("/content/TED.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3923 entries, 0 to 3922
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_link      3923 non-null   object
#  1   thumbnail_link  3268 non-null   object
#  2   duration        3923 non-null   object
#  3   title           3920 non-null   object
#  4   views           3920 non-null   object
#  5   likes           3922 non-null   object
#  6   comments        3856 non-null   object
#  7   date            3920 non-null   object
#  8   description     3910 non-null   object
# dtypes: object(9)
# memory usage: 276.0+ KB

# %%
df.head()
# Out:
#                                      video_link  \
# 0  https://www.youtube.com//watch?v=B5smctuV7-Q
# 1  https://www.youtube.com//watch?v=FrqBWQ-mVEc
# 2  https://www.youtube.com//watch?v=iIne-UO7wUo
# 3  https://www.youtube.com//watch?v=5T2VRY0LECc
# 4  https://www.youtube.com//watch?v=YRvf00NooN8
#
#                                      thumbnail_link  \
# 0  https://i.ytimg.com/vi/B5smctuV7-Q/hqdefault.jpg
# 1  https://i.ytimg.com/vi/FrqBWQ-mVEc/hqdefault.jpg
# 2  https://i.ytimg.com/vi/iIne-UO7wUo/hqdefault.jpg
# 3  https://i.ytimg.com/vi/5T2VRY0LECc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/YRvf00NooN8/hqdefault.jpg
#
#                         duration  \
# 0         14 minutes, 48 seconds
# 1          9 minutes, 53 seconds
# 2          9 minutes, 18 seconds
# 3          6 minutes, 56 seconds
# 4  1 hour, 6 minutes, 25 seconds
#
#                                                title      views likes  \
# 0  We Can Make COVID-19 the Last Pandemic | Bill ...    208,480  Like
# ...

# %%
df.shape
# Out:
# (3923, 9)

# %%
df.isna().sum()
# Out:
# video_link          0
# thumbnail_link    655
# duration            0
# title               3
# views               3
# likes               1
# comments           67
# date                3
# description        13
# dtype: int64

# %%
df_1 = pd.read_csv("/content/TED_Preprocessed.csv")

# %%
df_1.isna().sum()
# Out:
# video_link         0
# duration           0
# title              0
# views              0
# likes              0
# comments           0
# date               0
# month              0
# year               0
# date_month_year    0
# day                0
# dtype: int64

# %%
df_1.shape
# Out:
# (3845, 11)

# %%
df = pd.read_csv("/content/TED_Preprocessed.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3845 entries, 0 to 3844
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_link       3845 non-null   object
#  1   duration         3845 non-null   int64
#  2   title            3845 non-null   object
#  3   views            3845 non-null   int64
#  4   likes            3845 non-null   int64
#  5   comments         3845 non-null   int64
#  6   date             3845 non-null   int64
#  7   month            3845 non-null   int64
#  8   year             3845 non-null   int64
#  9   date_month_year  3845 non-null   object
#  10  day              3845 non-null   object
# dtypes: int64(7), object(4)
# memory usage: 330.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3845 entries, 0 to 3844
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_link       3845 non-null   object
#  1   duration         3845 non-null   int64
#  2   title            3845 non-null   object
#  3   views            3845 non-null   int64
#  4   likes            3845 non-null   int64
#  5   comments         3845 non-null   int64
#  6   date             3845 non-null   int64
#  7   month            3845 non-null   int64
#  8   year             3845 non-null   int64
#  9   date_month_year  3845 non-null   object
#  10  day              3845 non-null   object
# dtypes: int64(7), object(4)
# memory usage: 330.6+ KB

# %%
df.sample(5)
# Out:
#                                         video_link  duration  \
# 1181  https://www.youtube.com//watch?v=l4gJCBK0Tfc        12
# 990   https://www.youtube.com//watch?v=hokUdXYRe2Q        15
# 2691  https://www.youtube.com//watch?v=q1sk47FLAmg        11
# 1017  https://www.youtube.com//watch?v=m7hdIIneypE        14
# 1060  https://www.youtube.com//watch?v=6UbpxCQTv34        10
#
#                                                   title   views  likes  \
# 1181  How to start a conversation about suicide | Je...   76071   1700
# 990   The real reason female entrepreneurs get less ...  106374   2900
# 2691  Chris Gerdes: The future race car -- 150mph, a...   62278    829
# 1017                 Is civility a sham? | Teresa Bejan   69961   1900
# 1060               "New Second Line" | Camille A. Brown   38367    707
#
#       comments  date  month  year date_month_year  day
# 1181       131    15      6  2018       15/6/2018  Fri
# 990        249    18      1  2019       18/1/2019  Fri
# ...

# %%
df['year'].sort_values(ascending=False)
# Out:
# 0       2022
# 79      2022
# 92      2022
# 91      2022
# 90      2022
#         ...
# 3746    2007
# 3747    2007
# 3748    2007
# 3749    2007
# 3844    2006
# Name: year, Length: 3845, dtype: int64

# %%
df.loc[df['year'] >= 2020, ['title', 'views', 'year']].sort_values("views", ascending=False).head(10)
# Out:
#                                                  title    views  year
# 171  [Replay] Watch the 2021 TED Countdown Global L...  6128010  2021
# 414  What if a US presidential candidate refuses to...  4925964  2020
# 619  How we must respond to the coronavirus pandemi...  4858191  2020
# 4    Elon Musk talks Twitter, Tesla and how his bra...  4405481  2022
# 60   The War in Ukraine Could Change Everything | Y...  4136006  2022
# 3    Elon Musk: A future worth getting excited abou...  3609893  2022
# 225  A cleanse won't detox your body -- but here's ...  2191792  2021
# 522  How the pandemic will shape the near future | ...  1832099  2020
# 599  What coronavirus means for the global economy ...  1749527  2020
# 229  What's normal anxiety -- and what's an anxiety...  1713211  2021
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.loc[df['year'] >= 2020,['title', 'views', 'year']].head(10).plot\
                          (kind="bar", x="title", y="views", figsize=(10, 5))
# Out:
# <Axes: xlabel='title'>

# %%
df.head()
# Out:
#    duration                                              title    views  \
# 0        10  The Future Will Be Shaped by Optimists | Kevin...    51273
# 1         9  An Olympic Champion’s Unwavering Advocacy for ...    25597
# 2         7  The African Swamp Protecting Earth's Environme...    21430
# 3        66  Elon Musk: A future worth getting excited abou...  3609893
# 4        55  Elon Musk talks Twitter, Tesla and how his bra...  4405481
#
#     likes  comments  date  month  year date_month_year  day
# 0    1900       262    21      4  2022       21/4/2022  Thu
# 1     355        53    20      4  2022       20/4/2022  Wed
# 2     633        40    20      4  2022       20/4/2022  Wed
# 3   95000      8757    18      4  2022       18/4/2022  Mon
# 4  115000     10444    14      4  2022       14/4/2022  Thu

# %%
df.drop(columns=["date", "month", "day"], inplace=True)
# df.drop(columns=['vide_link'], inplace=True) has been already dropped

# %%
df
# Out:
#       duration                                              title     views  \
# 0           10  The Future Will Be Shaped by Optimists | Kevin...     51273
# 1            9  An Olympic Champion’s Unwavering Advocacy for ...     25597
# 2            7  The African Swamp Protecting Earth's Environme...     21430
# 3           66  Elon Musk: A future worth getting excited abou...   3609893
# 4           55  Elon Musk talks Twitter, Tesla and how his bra...   4405481
# ...        ...                                                ...       ...
# 3840        20     Do schools kill creativity? | Sir Ken Robinson  21363650
# 3841        19           Majora Carter: Greening the ghetto | TED    182713
# 3842         3               Dean Ornish: The world's killer diet    114595
# 3843         4  Secrets of success in 8 words, 3 minutes | Ric...   3028753
# 3844         4               If I controlled the Internet | Rives    360132
#
#        likes  comments  year date_month_year
# ...

# %%
df.groupby('year')['views'].sum()
# Out:
# year
# 2006       360132
# 2007     78923321
# 2008     89702176
# 2009    120317272
# 2010    108450866
# 2011    134633127
# 2012    199760868
# 2013    314023775
# 2014    188984208
# 2015    221761743
# 2016    255478284
# 2017    163299360
# 2018    131453820
# 2019     98600922
# 2020     58661972
# 2021     33111231
# 2022     19082863
# Name: views, dtype: int64

# %%
df.groupby('year')['views'].count()
# Out:
# year
# 2006      1
# 2007    147
# 2008    193
# 2009    216
# 2010    224
# 2011    243
# 2012    241
# 2013    235
# 2014    236
# 2015    254
# 2016    231
# 2017    268
# 2018    354
# 2019    290
# 2020    353
# 2021    235
# 2022    124
# Name: views, dtype: int64

# %%
df.shape[0]
# Out:
# 3845

# %%
# video title for each year
df.groupby('year')['title'].unique()
# Out:
# year
# 2006               [If I controlled the Internet | Rives]
# 2007    [Murray Gell-Mann: Beauty and truth in physics...
# 2008    [Jennifer 8. Lee: Who was General Tso? and oth...
# 2009    [Asher Hasan's message of peace from Pakistan,...
# 2010    [Why we have too few women leaders | Sheryl Sa...
# 2011    [Alberto Cairo: There are no scraps of men, Ka...
# 2012    [Israel and Iran: A love story?, Adam Davidson...
# 2013    [Never, ever give up | Diana Nyad, Does money ...
# 2014    [See invisible motion, hear silent sounds. Coo...
# 2015    [How we're growing baby corals to rebuild reef...
# 2016    [How an old loop of railroads is changing the ...
# 2017    [What AI is -- and isn't | Sebastian Thrun and...
# 2018    [How to motivate people to do good for others ...
# 2019    [The incredible chemistry powering your smartp...
# 2020    [The joy of taking out the trash | Aparna Nanc...
# 2021    [Amina J. Mohammed: A new perspective on the j...
# ...

# %%
df.columns
# Out:
# Index(['duration', 'title', 'views', 'likes', 'comments', 'year',
#        'date_month_year'],
#       dtype='object')

# %%
df.groupby('year')[['title', 'likes']].sum()
# Out:
#                                                   title    likes
# year
# 2006               If I controlled the Internet | Rives     3500
# 2007  Murray Gell-Mann: Beauty and truth in physicsR...   830580
# 2008  Jennifer 8. Lee: Who was General Tso? and othe...  1002568
# 2009  Asher Hasan's message of peace from PakistanSt...  1361143
# 2010  Why we have too few women leaders | Sheryl San...  1397971
# 2011  Alberto Cairo: There are no scraps of menKaren...  1619714
# 2012  Israel and Iran: A love story?Adam Davidson: W...  3192146
# 2013  Never, ever give up | Diana NyadDoes money mak...  5821407
# 2014  See invisible motion, hear silent sounds. Cool...  3222916
# 2015  How we're growing baby corals to rebuild reefs...  4521166
# 2016  How an old loop of railroads is changing the f...  6198868
# 2017  What AI is -- and isn't | Sebastian Thrun and ...  3925901
# 2018  How to motivate people to do good for others |...  3464726
# ...

# %%
df.groupby('year')[['title', 'likes', 'views']].sum().sort_values('views', ascending=False)
# Out:
#                                                   title    likes      views
# year
# 2013  Never, ever give up | Diana NyadDoes money mak...  5821407  314023775
# 2016  How an old loop of railroads is changing the f...  6198868  255478284
# 2015  How we're growing baby corals to rebuild reefs...  4521166  221761743
# 2012  Israel and Iran: A love story?Adam Davidson: W...  3192146  199760868
# 2014  See invisible motion, hear silent sounds. Cool...  3222916  188984208
# 2017  What AI is -- and isn't | Sebastian Thrun and ...  3925901  163299360
# 2011  Alberto Cairo: There are no scraps of menKaren...  1619714  134633127
# 2018  How to motivate people to do good for others |...  3464726  131453820
# 2009  Asher Hasan's message of peace from PakistanSt...  1361143  120317272
# 2010  Why we have too few women leaders | Sheryl San...  1397971  108450866
# 2019  The incredible chemistry powering your smartph...  2943594   98600922
# ...

# %%
df.sample(5)
# Out:
#       duration                                              title   views  \
# 3109        11        Peter Haas: Haiti's disaster of engineering   21638
# 1468         8  The stories behind The New Yorker's iconic cov...   51422
# 3816        20  David Deutsch: Chemical scum that dream of dis...  138734
# 249          6  Bianca Tylek: The multibillion-dollar US priso...   43641
# 3666         7                     Roy Gould: WorldWide Telescope   91116
#
#       likes  comments  year date_month_year
# 3109    219        60  2010      14/10/2010
# 1468    834        14  2017       17/8/2017
# 3816   1800       170  2007       16/1/2007
# 249    1600       450  2021        5/6/2021
# 3666    254        81  2008        1/3/2008

# %%
df["year"].value_counts()
# Out:
# year
# 2018    354
# 2020    353
# 2019    290
# 2017    268
# 2015    254
# 2011    243
# 2012    241
# 2014    236
# 2021    235
# 2013    235
# 2016    231
# 2010    224
# 2009    216
# 2008    193
# 2007    147
# 2022    124
# 2006      1
# Name: count, dtype: int64

# %%
df.groupby('year')['year'].count()
# Out:
# year
# 2006      1
# 2007    147
# 2008    193
# 2009    216
# 2010    224
# 2011    243
# 2012    241
# 2013    235
# 2014    236
# 2015    254
# 2016    231
# 2017    268
# 2018    354
# 2019    290
# 2020    353
# 2021    235
# 2022    124
# Name: year, dtype: int64

# %%
df.columns
# Out:
# Index(['duration', 'title', 'views', 'likes', 'comments', 'year',
#        'date_month_year'],
#       dtype='object')

# %%
df['duration'].value_counts()
# Out:
# duration
# 12    288
# 13    280
# 14    276
# 11    262
# 16    234
#      ...
# 43      1
# 61      1
# 45      1
# 48      1
# 53      1
# Name: count, Length: 64, dtype: int64

# %%
df['duration'].value_counts().head(10)
# Out:
# duration
# 12    288
# 13    280
# 14    276
# 11    262
# 16    234
# 15    230
# 17    227
# 10    223
# 6     204
# 18    204
# Name: count, dtype: int64

# %%
df['duration'].unique().shape
# Out:
# (64,)

# %%
df['duration'].value_counts().head(10).plot(kind='bar', x='duration', y='count', title='Top 10 duration of tedx videos')
# Out:
# <Axes: title={'center': 'Top 10 duration of tedx videos'}, xlabel='duration'>

# %%
df.columns
# Out:
# Index(['duration', 'title', 'views', 'likes', 'comments', 'year',
#        'date_month_year'],
#       dtype='object')

# %%
df.sort_values("duration").head(10)
# Out:
#      duration                                              title   views  \
# 435         0       What is net-zero? | Kristen Bell + Giant Ant   88715
# 167         0  How daylight saving time affects our bodies, m...  141205
# 434         0  Where does all the carbon we release go? | Kri...   67850
# 433         0  Why is 1.5 degrees such a big deal? | Kristen ...   88736
# 933         0             Get TED Talks recommended just for you   18978
# 432         0            Why act now? | Kristen Bell + Giant Ant   44772
# 431         0  Why is the world warming up? | Kristen Bell + ...  126036
# 136         1  How to deal with your insomnia — and finally g...   97185
# 208         1          We need to talk about shame | Brené Brown  147238
# 141         1  How sleep affects what -- and how much -- you ...  105044
#
#      likes  comments  year date_month_year
# 435   1500        76  2020      13/10/2020
# 167   4500       340  2021       3/11/2021
# ...

# %%
df.sort_values("duration").head(10)['year'].unique()
# Out:
# array([2020, 2021, 2019])

# %%
df.sort_values("duration").head(10).groupby('year')['views'].sum()
# Out:
# year
# 2019     18978
# 2020    416109
# 2021    490672
# Name: views, dtype: int64

# %%
df.sort_values("duration").head(10).groupby('year')['views'].sum().plot(kind='bar', x='year', y='views',\
                                                                        title='Sum of shortest tedx videos')
# Out:
# <Axes: title={'center': 'Sum of shortest tedx videos'}, xlabel='year'>

# %%
df.head()
# Out:
#    duration                                              title    views  \
# 0        10  The Future Will Be Shaped by Optimists | Kevin...    51273
# 1         9  An Olympic Champion’s Unwavering Advocacy for ...    25597
# 2         7  The African Swamp Protecting Earth's Environme...    21430
# 3        66  Elon Musk: A future worth getting excited abou...  3609893
# 4        55  Elon Musk talks Twitter, Tesla and how his bra...  4405481
#
#     likes  comments  year date_month_year
# 0    1900       262  2022       21/4/2022
# 1     355        53  2022       20/4/2022
# 2     633        40  2022       20/4/2022
# 3   95000      8757  2022       18/4/2022
# 4  115000     10444  2022       14/4/2022

# %%
df.sort_values(by="duration", ascending=False).head()
# Out:
#      duration                                              title    views  \
# 171       155  [Replay] Watch the 2021 TED Countdown Global L...  6128010
# 544        66       The path to ending systemic racism in the US   198223
# 3          66  Elon Musk: A future worth getting excited abou...  3609893
# 722        65  How we can turn the tide on climate | Christia...   333722
# 610        64  How we can navigate the pandemic with courage ...    63263
#
#      likes  comments  year date_month_year
# 171  20000      3663  2021      30/10/2021
# 544   1800       889  2020       10/6/2020
# 3    95000      8757  2022       18/4/2022
# 722   2400       434  2019      13/12/2019
# 610   1000       122  2020       31/3/2020

# %%
df.sort_values(by="duration", ascending=False).head(10).plot\
                          (kind="bar", x="title", y="duration", figsize=(10, 5))
# Out:
# <Axes: xlabel='title'>

# %%
df["views"].sum()
# Out:
# 2216605940

# %%
df.head()
# Out:
#    duration                                              title    views  \
# 0        10  The Future Will Be Shaped by Optimists | Kevin...    51273
# 1         9  An Olympic Champion’s Unwavering Advocacy for ...    25597
# 2         7  The African Swamp Protecting Earth's Environme...    21430
# 3        66  Elon Musk: A future worth getting excited abou...  3609893
# 4        55  Elon Musk talks Twitter, Tesla and how his bra...  4405481
#
#     likes  comments  year date_month_year
# 0    1900       262  2022       21/4/2022
# 1     355        53  2022       20/4/2022
# 2     633        40  2022       20/4/2022
# 3   95000      8757  2022       18/4/2022
# 4  115000     10444  2022       14/4/2022

# %%
df.groupby("year")["comments"].sum()
# Out:
# year
# 2006       401
# 2007     75631
# 2008    123426
# 2009     96301
# 2010    144104
# 2011    129590
# 2012    238181
# 2013    330021
# 2014    192793
# 2015    372755
# 2016    384988
# 2017    279602
# 2018    284027
# 2019    206172
# 2020    196894
# 2021     77242
# 2022     55525
# Name: comments, dtype: int64

# %%
df.groupby("year")["comments"].sum().plot(kind="bar", x="year", y="comments", figsize=(10, 5),\
                                          title="Total comments per year")
# Out:
# <Axes: title={'center': 'Total comments per year'}, xlabel='year'>

# %%
df.groupby("year")["likes"].sum()
# Out:
# year
# 2006       3500
# 2007     830580
# 2008    1002568
# 2009    1361143
# 2010    1397971
# 2011    1619714
# 2012    3192146
# 2013    5821407
# 2014    3222916
# 2015    4521166
# 2016    6198868
# 2017    3925901
# 2018    3464726
# 2019    2943594
# 2020    1630222
# 2021     860165
# 2022     405447
# Name: likes, dtype: int64

# %%
df.groupby("year")["likes"].sum().plot(kind="bar", x="year", y="likes", figsize=(10, 5),\
                                       title="Total likes per year")
# Out:
# <Axes: title={'center': 'Total likes per year'}, xlabel='year'>

# %%
df.groupby("year")["views"].sum()
# Out:
# year
# 2006       360132
# 2007     78923321
# 2008     89702176
# 2009    120317272
# 2010    108450866
# 2011    134633127
# 2012    199760868
# 2013    314023775
# 2014    188984208
# 2015    221761743
# 2016    255478284
# 2017    163299360
# 2018    131453820
# 2019     98600922
# 2020     58661972
# 2021     33111231
# 2022     19082863
# Name: views, dtype: int64

# %%
df.groupby("year")["views"].sum().plot(kind="bar", x="year", y="views", figsize=(10, 5),\
                                       title="Total views per year")
# Out:
# <Axes: title={'center': 'Total views per year'}, xlabel='year'>

# %%
df.head()
# Out:
#    duration                                              title    views  \
# 0        10  The Future Will Be Shaped by Optimists | Kevin...    51273
# 1         9  An Olympic Champion’s Unwavering Advocacy for ...    25597
# 2         7  The African Swamp Protecting Earth's Environme...    21430
# 3        66  Elon Musk: A future worth getting excited abou...  3609893
# 4        55  Elon Musk talks Twitter, Tesla and how his bra...  4405481
#
#     likes  comments  year date_month_year
# 0    1900       262  2022       21/4/2022
# 1     355        53  2022       20/4/2022
# 2     633        40  2022       20/4/2022
# 3   95000      8757  2022       18/4/2022
# 4  115000     10444  2022       14/4/2022

# %%
df.groupby("year")["duration"].sum()
# Out:
# year
# 2006       4
# 2007    2622
# 2008    3240
# 2009    2997
# 2010    3455
# 2011    3135
# 2012    3068
# 2013    2991
# 2014    2977
# 2015    3329
# 2016    2920
# 2017    3454
# 2018    3971
# 2019    3580
# 2020    4994
# 2021    2420
# 2022    1469
# Name: duration, dtype: int64

# %%
df.groupby("year")["duration"].sum().plot(kind="bar", x="year", y="duration", figsize=(10, 5),\
                                       title="Total duration per year")
# Out:
# <Axes: title={'center': 'Total duration per year'}, xlabel='year'>

# %%
df.head()
# Out:
#    duration                                              title    views  \
# 0        10  The Future Will Be Shaped by Optimists | Kevin...    51273
# 1         9  An Olympic Champion’s Unwavering Advocacy for ...    25597
# 2         7  The African Swamp Protecting Earth's Environme...    21430
# 3        66  Elon Musk: A future worth getting excited abou...  3609893
# 4        55  Elon Musk talks Twitter, Tesla and how his bra...  4405481
#
#     likes  comments  year date_month_year
# 0    1900       262  2022       21/4/2022
# 1     355        53  2022       20/4/2022
# 2     633        40  2022       20/4/2022
# 3   95000      8757  2022       18/4/2022
# 4  115000     10444  2022       14/4/2022

# %%
df.value_counts("date_month_year")
# Out:
# date_month_year
# 15/7/2015    32
# 18/7/2015    17
# 16/1/2007    14
# 17/1/2007    14
# 18/5/2007    12
#              ..
# 19/9/2020     1
# 2/1/2013      1
# 2/1/2014      1
# 2/1/2018      1
# 9/9/2020      1
# Name: count, Length: 2941, dtype: int64

# %%
df.value_counts("date_month_year").head(20)
# Out:
# date_month_year
# 15/7/2015     32
# 18/7/2015     17
# 16/1/2007     14
# 17/1/2007     14
# 18/5/2007     12
# 13/1/2007     11
# 14/2/2020      9
# 2/9/2020       8
# 10/2/2020      8
# 17/5/2007      8
# 9/2/2019       8
# 3/11/2018      8
# 15/4/2008      7
# 11/10/2008     7
# 13/10/2020     7
# 15/5/2007      6
# 15/9/2018      6
# 16/4/2008      6
# 21/6/2007      6
# 9/1/2008       5
# Name: count, dtype: int64

# %%
df.value_counts("date_month_year").head(20).plot(kind="bar", x="date_month_year", y="count", figsize=(10, 5),\
                                                 title="Top 20 dates where more than 1 videos were published")
# Out:
# <Axes: title={'center': 'Top 20 dates where more than 1 videos were published'}, xlabel='date_month_year'>

# %%
df.head()
# Out:
#    duration                                              title    views  \
# 0        10  The Future Will Be Shaped by Optimists | Kevin...    51273
# 1         9  An Olympic Champion’s Unwavering Advocacy for ...    25597
# 2         7  The African Swamp Protecting Earth's Environme...    21430
# 3        66  Elon Musk: A future worth getting excited abou...  3609893
# 4        55  Elon Musk talks Twitter, Tesla and how his bra...  4405481
#
#     likes  comments  year date_month_year
# 0    1900       262  2022       21/4/2022
# 1     355        53  2022       20/4/2022
# 2     633        40  2022       20/4/2022
# 3   95000      8757  2022       18/4/2022
# 4  115000     10444  2022       14/4/2022

# %%
df.loc[df["comments"] < 100].sort_values("comments")
# Out:
#       duration                                              title   views  \
# 1981        16         Emma Teeling: The secret of the bat genome    5699
# 1940        16     Jackie Tabick: The balancing act of compassion    9334
# 1290         3                      "My Fine Reward" | Tito Deler   15340
# 1982        10  Megan Kamerick: Women should represent women i...   12514
# 658         11  To challenge the status quo, find a "co-conspi...   11823
# ...        ...                                                ...     ...
# 1441        12  How your pictures can help reclaim lost histor...   76999
# 3285        16                Nick Veasey: Exposing the invisible   55939
# 2091        16  Zeynep Tufekci: How the Internet has made soci...  118679
# 1392        13  A pro wrestler's guide to confidence | Mike Ki...  133678
# 515          6  A path to higher education and employment for ...   37616
#
#       likes  comments  year date_month_year
# ...

# %%
df.loc[df["comments"] < 100, ['year',"comments", "title"]].sort_values("comments").groupby("year")['title'].unique()
# Out:
# year
# 2007    [David Rockwell: Building the Ground Zero view...
# 2008    [Steven Johnson: The Web and the city, Corneil...
# 2009    [The TED Fellows program, Katherine Fulton: Yo...
# 2010    [Lalitesh Katragadda: Making maps to fight dis...
# 2011    [Majora Carter: 3 stories of local eco-entrepr...
# 2012    [Paul Conneally: Digital humanitarianism, Mark...
# 2013    [Stefan Larsson: What doctors can learn from e...
# 2014    [Fields Wicker-Miurin: Learning from leadershi...
# 2015    [Emma Teeling: The secret of the bat genome, J...
# 2016    [Pirates, nurses and other rebel designers | A...
# 2017    [The stories behind The New Yorker's iconic co...
# 2018    ["My Fine Reward" | Tito Deler, How work kept ...
# 2019    [Get TED Talks recommended just for you, This ...
# 2020    [To challenge the status quo, find a "co-consp...
# 2021    [Possible futures from the intersection of nat...
# 2022    [Dwan Reece: The origins of blackface and Blac...
# Name: title, dtype: object

# %%
df.sample(5)
# Out:
#       duration                                              title    views  \
# 3753        20  John Doerr: Seeking salvation and profit in gr...    78455
# 389         12  Climate change is becoming a problem you can t...    94532
# 3579        31   Close-up card magic with a twist | Lennart Green  2921967
# 1066         6  3 lessons on decision-making from a poker cham...   875247
# 1735         4                                 Ideas worth dating   131970
#
#       likes  comments  year date_month_year
# 3753    384        73  2007       31/5/2007
# 389    3200       678  2020      17/11/2020
# 3579  26000      1604  2008       21/8/2008
# 1066  21000       631  2018      22/10/2018
# 1735   3100       150  2016       27/6/2016

# %%
correlation_matrix = df[['views', 'likes', 'comments','duration', 'year']].corr()

# %%
correlation_matrix
# Out:
#              views     likes  comments  duration      year
# views     1.000000  0.925798  0.731278  0.086990 -0.064520
# likes     0.925798  1.000000  0.761628  0.056517 -0.004915
# comments  0.731278  0.761628  1.000000  0.104488 -0.002377
# duration  0.086990  0.056517  0.104488  1.000000 -0.167346
# year     -0.064520 -0.004915 -0.002377 -0.167346  1.000000

# %%
# plot in heatmap
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True)
plt.show()
