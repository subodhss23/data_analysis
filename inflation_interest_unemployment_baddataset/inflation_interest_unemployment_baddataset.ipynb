# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
sns.set(style='whitegrid', color_codes=True)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("/content/inflation interest unemployment.csv")

# %%
df.head()
# Out:
#        country  year  Inflation, consumer prices (annual %)  \
# 0  Afghanistan  1970                                    NaN
# 1  Afghanistan  1971                                    NaN
# 2  Afghanistan  1972                                    NaN
# 3  Afghanistan  1973                                    NaN
# 4  Afghanistan  1974                                    NaN
#
#    Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#    Deposit interest rate (%)  Lending interest rate (%)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
df.isna().sum()
# Out:
# country                                                                   0
# year                                                                      0
# Inflation, consumer prices (annual %)                                  4250
# Inflation, GDP deflator (annual %)                                     2851
# Real interest rate (%)                                                 9661
# Deposit interest rate (%)                                              9245
# Lending interest rate (%)                                              9419
# Unemployment, total (% of total labor force) (national estimate)       8657
# Unemployment, total (% of total labor force) (modeled ILO estimate)    6547
# iso3c                                                                   104
# iso2c                                                                   156
# adminregion                                                            6708
# ...

# %%
df.isna().mean()*100
# Out:
# country                                                                 0.000000
# year                                                                    0.000000
# Inflation, consumer prices (annual %)                                  30.725853
# Inflation, GDP deflator (annual %)                                     20.611625
# Real interest rate (%)                                                 69.845286
# Deposit interest rate (%)                                              66.837767
# Lending interest rate (%)                                              68.095720
# Unemployment, total (% of total labor force) (national estimate)       62.586755
# Unemployment, total (% of total labor force) (modeled ILO estimate)    47.332273
# iso3c                                                                   0.751880
# iso2c                                                                   1.127820
# adminregion                                                            48.496241
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13832 entries, 0 to 13831
# Data columns (total 13 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   country                                                              13832 non-null  object
#  1   year                                                                 13832 non-null  int64
#  2   Inflation, consumer prices (annual %)                                9582 non-null   float64
#  3   Inflation, GDP deflator (annual %)                                   10981 non-null  float64
#  4   Real interest rate (%)                                               4171 non-null   float64
#  5   Deposit interest rate (%)                                            4587 non-null   float64
# ...

# %%
df["country"].value_counts()
# Out:
# country
# Afghanistan                                             52
# Norway                                                  52
# Mozambique                                              52
# Myanmar                                                 52
# Namibia                                                 52
# Nauru                                                   52
# Nepal                                                   52
# Netherlands                                             52
# New Caledonia                                           52
# New Zealand                                             52
# Nicaragua                                               52
# Niger                                                   52
# Nigeria                                                 52
# North America                                           52
# North Macedonia                                         52
# Northern Mariana Islands                                52
# ...

# %%
df.columns
# Out:
# Index(['country', 'year', 'Inflation, consumer prices (annual %)',
#        'Inflation, GDP deflator (annual %)', 'Real interest rate (%)',
#        'Deposit interest rate (%)', 'Lending interest rate (%)',
#        'Unemployment, total (% of total labor force) (national estimate)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        'iso3c', 'iso2c', 'adminregion', 'incomeLevel'],
#       dtype='object')

# %%
us_latest_data_17_21 = df[df['country'] == "United States"].tail()

# %%
us_latest_data_17_21
# Out:
#              country  year  Inflation, consumer prices (annual %)  \
# 13203  United States  2017                               2.130110
# 13204  United States  2018                               2.442583
# 13205  United States  2019                               1.812210
# 13206  United States  2020                               1.233584
# 13207  United States  2021                               4.697859
#
#        Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 13203                            1.880068                2.175694
# 13204                            2.400981                2.444494
# 13205                            1.785152                3.436010
# 13206                            1.205202                2.311111
# 13207                                 NaN                     NaN
#
#        Deposit interest rate (%)  Lending interest rate (%)  \
# 13203                        NaN                   4.096667
# ...

# %%
us_latest_data_17_21['Inflation, consumer prices (annual %)'].plot(kind='bar', x="year", xlabel="year", y="Inflation, consumer prices (annual %)")
# Out:
# <Axes: xlabel='year'>

# %%
us_latest_data_17_21['Inflation, consumer prices (annual %)'].plot(kind='line', x="year", xlabel="year", y="Inflation, consumer prices (annual %)")
# Out:
# <Axes: xlabel='year'>

# %%
us_latest_data_17_21['Inflation, consumer prices (annual %)'].mean()
# Out:
# 2.4632693271583443

# %%
us_latest_data_17_21['Unemployment, total (% of total labor force) (national estimate)'].mean()
# Out:
# 5.066000080108641

# %%
us_latest_data_17_21['Unemployment, total (% of total labor force) (modeled ILO estimate)'].mean()
# Out:
# 5.088800144195555

# %%
us_latest_data_17_21["Real interest rate (%)"].plot(kind="line", x="year", y="Real interest rate (%)")
# Out:
# <Axes: >

# %%
us_latest_data_17_21["Real interest rate (%)"].mean()
# Out:
# 2.5918274677050577

# %%
us_latest_data_17_21["Lending interest rate (%)"].mean()
# Out:
# 4.215500000000001

# %%
df.sample(2)
# Out:
#         country  year  Inflation, consumer prices (annual %)  \
# 5464  IBRD only  1974                              19.357743
# 3119   Djibouti  2021                                    NaN
#
#       Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 5464                            23.74288                     NaN
# 3119                                 NaN                     NaN
#
#       Deposit interest rate (%)  Lending interest rate (%)  \
# 5464                        NaN                        NaN
# 3119                        NaN                        NaN
#
#       Unemployment, total (% of total labor force) (national estimate)  \
# 5464                                                NaN
# 3119                                                NaN
#
#       Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 5464                                                NaN
# 3119                                             28.386
#
# ...

# %%
df.shape
# Out:
# (13832, 13)

# %%
df_copy = df.copy()

# %%
df_copy.dropna(inplace=True)

# %%
df_copy.shape
# Out:
# (1266, 13)

# %%
df[df['country'] == 'Nepal']
# Out:
#      country  year  Inflation, consumer prices (annual %)  \
# 8944   Nepal  1970                              15.237278
# 8945   Nepal  1971                              -1.999504
# 8946   Nepal  1972                               8.389024
# 8947   Nepal  1973                              11.429773
# 8948   Nepal  1974                              19.806338
# 8949   Nepal  1975                               7.585985
# 8950   Nepal  1976                              -3.113236
# 8951   Nepal  1977                               9.898853
# 8952   Nepal  1978                               7.346091
# 8953   Nepal  1979                               3.565454
# 8954   Nepal  1980                              14.684503
# 8955   Nepal  1981                              11.144857
# 8956   Nepal  1982                              11.698547
# 8957   Nepal  1983                              12.377238
# 8958   Nepal  1984                               2.845785
# ...

# %%
latest_data_nepal_17_21 = df[df['country'] == 'Nepal'].tail()

# %%
latest_data_nepal_17_21
# Out:
#      country  year  Inflation, consumer prices (annual %)  \
# 8991   Nepal  2017                               3.627096
# 8992   Nepal  2018                               4.061163
# 8993   Nepal  2019                               5.568685
# 8994   Nepal  2020                               5.052367
# 8995   Nepal  2021                               4.087910
#
#       Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 8991                            8.261413                     NaN
# 8992                            4.355858                     NaN
# 8993                            4.691156                     NaN
# 8994                            3.608984                     NaN
# 8995                                 NaN                     NaN
#
#       Deposit interest rate (%)  Lending interest rate (%)  \
# 8991                        NaN                        NaN
# 8992                        NaN                        NaN
# ...

# %%
latest_data_nepal_17_21['Unemployment, total (% of total labor force) (modeled ILO estimate)'].plot(kind="bar", x="year",y="Unemployment, total (% of total labor force) (modeled ILO estimate)")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#        country  year  Inflation, consumer prices (annual %)  \
# 0  Afghanistan  1970                                    NaN
# 1  Afghanistan  1971                                    NaN
# 2  Afghanistan  1972                                    NaN
# 3  Afghanistan  1973                                    NaN
# 4  Afghanistan  1974                                    NaN
#
#    Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#    Deposit interest rate (%)  Lending interest rate (%)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
df['year'].value_counts()
# Out:
# year
# 1970    266
# 1971    266
# 1998    266
# 1999    266
# 2000    266
# 2001    266
# 2002    266
# 2003    266
# 2004    266
# 2005    266
# 2006    266
# 2007    266
# 2008    266
# 2009    266
# 2010    266
# 2011    266
# 2012    266
# 2013    266
# 2014    266
# 2015    266
# 2016    266
# 2017    266
# 2018    266
# 2019    266
# 2020    266
# 1997    266
# 1996    266
# 1995    266
# 1982    266
# 1972    266
# 1973    266
# 1974    266
# 1975    266
# 1976    266
# 1977    266
# 1978    266
# 1979    266
# 1980    266
# 1981    266
# 1983    266
# 1994    266
# 1984    266
# 1985    266
# 1986    266
# 1987    266
# 1988    266
# 1989    266
# 1990    266
# 1991    266
# 1992    266
# 1993    266
# 2021    266
# Name: count, dtype: int64

# %%
df["adminregion"].value_counts()
# Out:
# adminregion
# Sub-Saharan Africa (excluding high income)            2444
# Latin America & Caribbean (excluding high income)     1300
# East Asia & Pacific (excluding high income)           1196
# Europe & Central Asia (excluding high income)         1092
# Middle East & North Africa (excluding high income)     676
# South Asia                                             416
# Name: count, dtype: int64

# %%
df['incomeLevel'].value_counts()
# Out:
# incomeLevel
# High income            4108
# Upper middle income    2860
# Lower middle income    2860
# Aggregates             2444
# Low income             1404
# Not classified           52
# Name: count, dtype: int64

# %%
df['incomeLevel'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='incomeLevel'>

# %%
matrix_correlation = df.corr(numeric_only=True)

# %%
matrix_correlation
# Out:
#                                                         year  \
# year                                                1.000000
# Inflation, consumer prices (annual %)              -0.030263
# Inflation, GDP deflator (annual %)                 -0.027501
# Real interest rate (%)                              0.075997
# Deposit interest rate (%)                          -0.024073
# Lending interest rate (%)                          -0.021864
# Unemployment, total (% of total labor force) (n...  0.052665
# Unemployment, total (% of total labor force) (m... -0.026079
#
#                                                     Inflation, consumer prices (annual %)  \
# year                                                                            -0.030263
# Inflation, consumer prices (annual %)                                            1.000000
# Inflation, GDP deflator (annual %)                                               0.990216
# ...

# %%
# heatmap for matrix_correlation
plt.figure(figsize=(10,10))
sns.heatmap(matrix_correlation, annot=True)
# Out:
# <Axes: >

# %%
# pairplot
sns.pairplot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-276-5ff17a07d2b0> in <cell line: 2>()
#       1 # pairplot
# ----> 2 sns.pairplot(df)
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2147     diag_kws.setdefault("legend", False)
#    2148     if diag_kind == "hist":
# -> 2149         grid.map_diag(histplot, **diag_kws)
#    2150     elif diag_kind == "kde":
#    2151         diag_kws.setdefault("fill", True)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1511             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1512             plot_kwargs.setdefault("palette", self._orig_palette)
# ...
