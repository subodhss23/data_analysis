# %%
import pandas as pd

# %%
df = pd.read_csv("/content/CPU_benchmark_v4.csv")

# %%
df.isna().sum()
# Out:
# cpuName           0
# price          1858
# cpuMark           0
# cpuValue       1858
# threadMark        0
# threadValue    1858
# TDP             685
# powerPerf       685
# cores             0
# testDate          0
# socket            0
# category          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3825 entries, 0 to 3824
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cpuName      3825 non-null   object
#  1   price        1967 non-null   float64
#  2   cpuMark      3825 non-null   int64
#  3   cpuValue     1967 non-null   float64
#  4   threadMark   3825 non-null   int64
#  5   threadValue  1967 non-null   float64
#  6   TDP          3140 non-null   float64
#  7   powerPerf    3140 non-null   object
#  8   cores        3825 non-null   int64
#  9   testDate     3825 non-null   int64
#  10  socket       3825 non-null   object
#  11  category     3825 non-null   object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 358.7+ KB

# %%
df_1 = pd.read_csv("/content/CPU_r23_v2.csv")

# %%
df_1.isna().sum()
# Out:
# manufacturer    0
# cpuName         0
# singleScore     0
# multiScore      0
# cores           0
# threads         0
# baseClock       0
# turboClock      0
# type            0
# dtype: int64

# %%
df = pd.read_csv("/content/CPU_r23_v2.csv")

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
df.isna().sum()
# Out:
# manufacturer    0
# cpuName         0
# singleScore     0
# multiScore      0
# cores           0
# threads         0
# baseClock       0
# turboClock      0
# type            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  215 non-null    object
#  1   cpuName       215 non-null    object
#  2   singleScore   215 non-null    int64
#  3   multiScore    215 non-null    int64
#  4   cores         215 non-null    int64
#  5   threads       215 non-null    int64
#  6   baseClock     215 non-null    float64
#  7   turboClock    215 non-null    float64
#  8   type          215 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 15.2+ KB

# %%
df.sample(10)
# Out:
#     manufacturer              cpuName  singleScore  multiScore  cores  \
# 106          AMD       Ryzen 9 4900HS         1250       11145      8
# 123        Intel       Core i7 10870H         1235        9986      8
# 46         Intel        Core i9 9920X         1077       15018     12
# 5            AMD   Threadripper 3960X         1307       34932     24
# 6            AMD  Threadripper 2990WX         1005       29651     32
# 0            AMD   Threadripper 3990X         1262       75671     64
# 125          AMD       Ryzen 5 3600XT         1330        9945      6
# 60         Intel        Core i9 11900         1473       13499      8
# 177        Intel        Core i7 6850K         1004        7422      6
# 13           AMD        Ryzen 9 3950X         1406       26375     16
#
#      threads  baseClock  turboClock     type
# 106       16        3.0         4.3   Laptop
# 123       16        2.2         5.0   Laptop
# 46        24        3.5         4.4  Desktop
# ...

# %%
df['manufacturer'].value_counts()
# Out:
# manufacturer
# Intel    125
# AMD       86
# Apple      4
# Name: count, dtype: int64

# %%
df['manufacturer'].value_counts().plot(kind="bar", figsize=(10, 5), x="manufacturer", y="count")
# Out:
# <Axes: xlabel='manufacturer'>

# %%
df["type"].value_counts()
# Out:
# type
# Desktop    144
# Laptop      71
# Name: count, dtype: int64

# %%
df["type"].value_counts().plot(kind="bar", x="type", y="count")
# Out:
# <Axes: xlabel='type'>

# %%
df.columns
# Out:
# Index(['manufacturer', 'cpuName', 'singleScore', 'multiScore', 'cores',
#        'threads', 'baseClock', 'turboClock', 'type'],
#       dtype='object')

# %%
df.groupby('manufacturer')['cpuName'].unique()
# Out:
# manufacturer
# AMD      [Threadripper 3990X, Threadripper Pro 3995WX, ...
# Apple                       [M1 Ultra, M1 Max, M1 Pro, M1]
# Intel    [Core i9 12900K, Core i9 12900KF, Core i9 1290...
# Name: cpuName, dtype: object

# %%
# count total cpu from each manufacturer
df.groupby('manufacturer')['cpuName'].count()
# Out:
# manufacturer
# AMD       86
# Apple      4
# Intel    125
# Name: cpuName, dtype: int64

# %%
df.loc[df['manufacturer'] == "Apple"]
# Out:
#     manufacturer   cpuName  singleScore  multiScore  cores  threads  \
# 18         Apple  M1 Ultra         1574       21817     20       20
# 82         Apple    M1 Max         1556       12553     10       10
# 88         Apple    M1 Pro         1552       12311     10       10
# 168        Apple        M1         1533        7850      8        8
#
#      baseClock  turboClock     type
# 18         2.0         3.2  Desktop
# 82         2.0         3.2   Laptop
# 88         2.0         3.2   Laptop
# 168        2.1         3.2   Laptop

# %%
df.loc[df['cores'] > 8].shape[0]
# Out:
# 54

# %%
df.loc[df['cores'] > 8]
# Out:
#     manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0            AMD       Threadripper 3990X         1262       75671     64
# 1            AMD  Threadripper Pro 3995WX         1231       73220     64
# 2            AMD               Epyc 7702P          993       48959     64
# 3            AMD       Threadripper 3970X         1308       46874     32
# 4            AMD  Threadripper Pro 3975WX         1244       43450     32
# 5            AMD       Threadripper 3960X         1307       34932     24
# 6            AMD      Threadripper 2990WX         1005       29651     32
# 7            AMD            Ryzen 9 5950X         1684       28782     16
# 8          Intel           Core i9 12900K         2007       27852     16
# 9          Intel          Core i9 12900KF         1974       27852     16
# 10         Intel          Core i9 12900KS         2082       27796     16
# 11           AMD  Threadripper Pro 3955WX         1401       27175     16
# ...

# %%
df.loc[df['cores'] > 8].value_counts("manufacturer")
# Out:
# manufacturer
# Intel    34
# AMD      17
# Apple     3
# Name: count, dtype: int64

# %%
df.loc[df['cores'] > 8].value_counts("manufacturer").plot(kind="bar", \
          title="CPU more that has more than 8 cores", ylabel="num of cores")
# Out:
# <Axes: title={'center': 'CPU more that has more than 8 cores'}, xlabel='manufacturer', ylabel='num of cores'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
df.sort_values("singleScore", ascending=False).head(10)
# Out:
#    manufacturer          cpuName  singleScore  multiScore  cores  threads  \
# 10        Intel  Core i9 12900KS         2082       27796     16       24
# 8         Intel   Core i9 12900K         2007       27852     16       24
# 9         Intel  Core i9 12900KF         1974       27852     16       24
# 16        Intel  Core i7 12700KF         1958       22997     12       20
# 15        Intel   Core i7 12700K         1950       23168     12       20
# 31        Intel   Core i9 12900H         1948       16839     14       20
# 27        Intel  Core i5 12600KF         1929       17979     10       16
# 25        Intel  Core i9 12900HK         1919       18252     14       20
# 29        Intel   Core i5 12600K         1904       17400     10       16
# 34        Intel    Core i7 12700         1875       16225     12       20
#
#     baseClock  turboClock     type
# 10        3.4         5.5  Desktop
# 8         3.2         5.2  Desktop
# 9         3.2         5.2  Desktop
# ...

# %%
df.sort_values("singleScore", ascending=False).head(10).plot(kind="bar", x="cpuName", y="singleScore",\
                        title="Top 10 CPU with highest single score")
# Out:
# <Axes: title={'center': 'Top 10 CPU with highest single score'}, xlabel='cpuName'>

# %%
df.sort_values("multiScore", ascending=False).head(10)
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
# 5          AMD       Threadripper 3960X         1307       34932     24
# 6          AMD      Threadripper 2990WX         1005       29651     32
# 7          AMD            Ryzen 9 5950X         1684       28782     16
# 8        Intel           Core i9 12900K         2007       27852     16
# 9        Intel          Core i9 12900KF         1974       27852     16
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# ...

# %%
df.sort_values("multiScore", ascending=False).head(10).plot(kind="bar", x="cpuName", y="multiScore", \
                                                            title="Top 10 CPU for multi score")
# Out:
# <Axes: title={'center': 'Top 10 CPU for multi score'}, xlabel='cpuName'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
df.shape
# Out:
# (215, 9)

# %%
df.groupby("type")['cores'].unique()
# Out:
# type
# Desktop    [64, 32, 24, 16, 18, 12, 20, 10, 14, 8, 6, 4]
# Laptop                             [14, 8, 12, 10, 6, 4]
# Name: cores, dtype: object

# %%
df.groupby("type")['threads'].unique()
# Out:
# type
# Desktop    [128, 64, 32, 24, 36, 20, 16, 28, 12, 8, 6]
# Laptop                          [20, 16, 10, 12, 8, 6]
# Name: threads, dtype: object

# %%
df.groupby("manufacturer")['cores'].unique()
# Out:
# manufacturer
# AMD      [64, 32, 24, 16, 12, 8, 6, 4]
# Apple                      [20, 10, 8]
# Intel    [16, 18, 12, 14, 10, 8, 6, 4]
# Name: cores, dtype: object

# %%
df.groupby("manufacturer")['threads'].unique()
# Out:
# manufacturer
# AMD         [128, 64, 32, 24, 16, 12, 8, 6]
# Apple                           [20, 10, 8]
# Intel    [24, 36, 20, 32, 16, 28, 12, 8, 6]
# Name: threads, dtype: object

# %%
df.columns
# Out:
# Index(['manufacturer', 'cpuName', 'singleScore', 'multiScore', 'cores',
#        'threads', 'baseClock', 'turboClock', 'type'],
#       dtype='object')

# %%
df.loc[df["manufacturer"] == "Apple", ["cpuName", "baseClock", "turboClock"]]
# Out:
#       cpuName  baseClock  turboClock
# 18   M1 Ultra        2.0         3.2
# 82     M1 Max        2.0         3.2
# 88     M1 Pro        2.0         3.2
# 168        M1        2.1         3.2

# %%
df.loc[df["manufacturer"] == "Apple", ["cpuName", "baseClock", "turboClock"]].plot\
                (kind='bar', title="Apple CPU Performance", x = "cpuName", xlabel="CPU Name", ylabel="Clock Speed")
# Out:
# <Axes: title={'center': 'Apple CPU Performance'}, xlabel='CPU Name', ylabel='Clock Speed'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
df.loc[df["cores"] == 32,["cpuName", "cores", "singleScore", "multiScore",]]
# Out:
#                    cpuName  cores  singleScore  multiScore
# 0       Threadripper 3990X     64         1262       75671
# 1  Threadripper Pro 3995WX     64         1231       73220
# 2               Epyc 7702P     64          993       48959
# 3       Threadripper 3970X     32         1308       46874
# 4  Threadripper Pro 3975WX     32         1244       43450
# 6      Threadripper 2990WX     32         1005       29651

# %%
df.loc[df["cores"] == 32, ["cpuName", "cores", "singleScore", "multiScore"]].plot\
                (kind="bar", title="CPU with 32 cores", x="cpuName", y=["singleScore", "multiScore"])
# Out:
# <Axes: title={'center': 'CPU with 32 cores'}, xlabel='cpuName'>

# %%
df.loc[df["cores"] == 64, ["cpuName", "cores", "singleScore", "multiScore"]].plot\
                (kind="bar", title="CPU with 64 cores", x="cpuName", y=["singleScore", "multiScore"])
# Out:
# <Axes: title={'center': 'CPU with 64 cores'}, xlabel='cpuName'>

# %%
df.loc[df["cores"] == 32, ["cpuName", "cores", "singleScore", "multiScore", "manufacturer"]]
# Out:
#                    cpuName  cores  singleScore  multiScore manufacturer
# 3       Threadripper 3970X     32         1308       46874          AMD
# 4  Threadripper Pro 3975WX     32         1244       43450          AMD
# 6      Threadripper 2990WX     32         1005       29651          AMD

# %%
df.loc[df["cores"] == 64, ["cpuName", "cores", "singleScore", "multiScore", "manufacturer"]]
# Out:
#                    cpuName  cores  singleScore  multiScore manufacturer
# 0       Threadripper 3990X     64         1262       75671          AMD
# 1  Threadripper Pro 3995WX     64         1231       73220          AMD
# 2               Epyc 7702P     64          993       48959          AMD

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
df.sample(5)
# Out:
#     manufacturer         cpuName  singleScore  multiScore  cores  threads  \
# 211        Intel  Core i7 1185G7         1473        5783      4        8
# 72         Intel  Core i9 9900KS         1289       12879      8       16
# 125          AMD  Ryzen 5 3600XT         1330        9945      6       12
# 129        Intel  Core i5 11500H         1511        9693      6       12
# 139        Intel  Core i7 9700KF         1261        9346      8        8
#
#      baseClock  turboClock     type
# 211        1.2         4.8   Laptop
# 72         4.0         5.0  Desktop
# 125        3.8         4.2  Desktop
# 129        2.4         4.6   Laptop
# 139        3.6         4.9  Desktop

# %%
df.loc[df["type"] == "Laptop"]
# Out:
#     manufacturer          cpuName  singleScore  multiScore  cores  threads  \
# 25         Intel  Core i9 12900HK         1919       18252     14       20
# 30         Intel   Core i7 12700H         1774       16860     14       20
# 31         Intel   Core i9 12900H         1948       16839     14       20
# 36         Intel   Core i7 12800H         1837       15922     14       20
# 47           AMD   Ryzen 9 6980HS         1685       14950      8       16
# ..           ...              ...          ...         ...    ...      ...
# 205        Intel   Core i5 11320H         1473        5995      4        8
# 206        Intel   Core i7 10710U         1270        5974      6       12
# 209          AMD    Ryzen 5 4500U         1151        5939      6        6
# 211        Intel   Core i7 1185G7         1473        5783      4        8
# 212        Intel   Core i7 11370H         1535        5778      4        8
#
#      baseClock  turboClock    type
# ...

# %%
top_single_score_laptop = df.loc[df["type"] == "Laptop", ["singleScore"]].sort_values("singleScore", ascending=False).head(2)
top_multi_score_laptop = df.loc[df["type"] == "Laptop", ["multiScore"]].sort_values("multiScore", ascending=False).head(2)
top_single_score_desktop = df.loc[df["type"] == "Desktop", ["singleScore"]].sort_values("singleScore", ascending=False).head(2)
top_multi_score_desktop = df.loc[df["type"] == "Desktop", ["multiScore"]].sort_values("multiScore", ascending=False).head(2)

# %%
# plot top singleScore of a laptop and desktop
top_single_score_laptop.plot(kind="bar", title="Top Single Score Laptop", xlabel="CPU Name", ylabel="Single Score")
# Out:
# <Axes: title={'center': 'Top Single Score Laptop'}, xlabel='CPU Name', ylabel='Single Score'>

# %%
# plot and compare top_single_score_laptop and top_single_score_desktop
top_single_score_laptop.plot(kind="bar", title="Top Single Score Laptop", xlabel="CPU Name", ylabel="Single Score")
top_single_score_desktop.plot(kind="bar", title="Top Single Score Desktop", xlabel="CPU Name", ylabel="Single Score")
# Out:
# <Axes: title={'center': 'Top Single Score Desktop'}, xlabel='CPU Name', ylabel='Single Score'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
top_single_score = pd.DataFrame({
    "Laptop Single Score": df.loc[df["type"] == "Laptop", ["singleScore"]].sort_values("singleScore", ascending=False).iloc[0],
    "Desktop Single Score": df.loc[df["type"] == "Desktop", ["singleScore"]].sort_values("singleScore", ascending=False).iloc(0)
}, index=[0])

# %%
top_single_score
# Out:
#    Laptop Single Score                               Desktop Single Score
# 0                  NaN  <pandas.core.indexing._iLocIndexer object at 0...

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
# compare the singleScore of type = Desktop and type = Laptop
top_single_score_desktop = df.loc[df["type"] == "Desktop", ["singleScore"]].sort_values("singleScore", ascending=False).iloc[0]
top_single_score_laptop = df.loc[df["type"] == "Laptop", ["singleScore"]].sort_values("singleScore", ascending=False).iloc[0]

# %%
top_single_score_desktop
# Out:
# singleScore    2082
# Name: 10, dtype: int64

# %%
top_single_score_laptop
# Out:
# singleScore    1948
# Name: 31, dtype: int64

# %%
top_scores_df = pd.DataFrame({
    'Type': ['Desktop', 'Laptop'],
    'singleScore': [top_single_score_desktop.values[0], top_single_score_laptop.values[0]]
})

# %%
top_scores_df.plot(kind="bar", x="Type", y="singleScore", title="Top Single Score")
# Out:
# <Axes: title={'center': 'Top Single Score'}, xlabel='Type'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
# compare the multiScore of type = Desktop and type = Laptop
top_multi_score_desktop = df.loc[df["type"] == "Desktop", ["multiScore"]].sort_values("multiScore", ascending=False).iloc[0]
top_multi_score_laptop = df.loc[df["type"] == "Laptop", ["multiScore"]].sort_values("multiScore", ascending=False).iloc[0]

# %%
top_multi_scores_df = pd.DataFrame({
    'Type': ['Laptop', 'Desktop'],
    'multiScore': [top_multi_score_laptop.values[0], top_multi_score_desktop.values[0]]
})

# %%
top_multi_scores_df.plot(kind="bar", x="Type", y="multiScore", title="Top Multi Score")
# Out:
# <Axes: title={'center': 'Top Multi Score'}, xlabel='Type'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
# how many cpus for laptop
df.loc[df["type"] == "Laptop"].shape[0]
# Out:
# 71

# %%
# how many cpu for desktop
df.loc[df["type"] == "Desktop"].shape[0]
# Out:
# 144

# %%
df.shape[0]
# Out:
# 215

# %%
# count number of laptops and desktops by different manufacturers
df.groupby("manufacturer")["type"].value_counts()
# Out:
# manufacturer  type
# AMD           Desktop    55
#               Laptop     31
# Apple         Laptop      3
#               Desktop     1
# Intel         Desktop    88
#               Laptop     37
# Name: count, dtype: int64

# %%
# plot df.groupby("manufacturer")["type"].value_counts()
df.groupby("manufacturer")["type"].value_counts().plot(kind="bar", x="manufacturer", y="count")
# Out:
# <Axes: xlabel='manufacturer,type'>

# %%
df.head()
# Out:
#   manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0          AMD       Threadripper 3990X         1262       75671     64
# 1          AMD  Threadripper Pro 3995WX         1231       73220     64
# 2          AMD               Epyc 7702P          993       48959     64
# 3          AMD       Threadripper 3970X         1308       46874     32
# 4          AMD  Threadripper Pro 3975WX         1244       43450     32
#
#    threads  baseClock  turboClock     type
# 0      128        2.9        4.50  Desktop
# 1      128        2.7        4.20  Desktop
# 2      128        2.0        3.35  Desktop
# 3       64        3.7        4.50  Desktop
# 4       64        3.5        4.20  Desktop

# %%
list_of_cpu_by_manufacturer = df.groupby("manufacturer")["cpuName"].unique()

# %%
print(type(list_of_cpu_by_manufacturer))
# Out:
# <class 'pandas.core.series.Series'>

# %%
for cpu_name in list_of_cpu_by_manufacturer:
  print(cpu_name.shape[0])
# Out:
# 86
# 4
# 125

# %%
correlation_matrix = df[["singleScore", "multiScore", "cores", "threads", "baseClock", "turboClock"]].corr()

# %%
correlation_matrix
# Out:
#              singleScore  multiScore     cores   threads  baseClock  \
# singleScore     1.000000    0.165598 -0.028463 -0.087273  -0.048699
# multiScore      0.165598    1.000000  0.931470  0.924025   0.110160
# cores          -0.028463    0.931470  1.000000  0.981211  -0.040486
# threads        -0.087273    0.924025  0.981211  1.000000  -0.003516
# baseClock      -0.048699    0.110160 -0.040486 -0.003516   1.000000
# turboClock      0.527882    0.078537 -0.088361 -0.071200   0.108281
#
#              turboClock
# singleScore    0.527882
# multiScore     0.078537
# cores         -0.088361
# threads       -0.071200
# baseClock      0.108281
# turboClock     1.000000

# %%
# use seaborn for pairplot
import seaborn as sns
sns.pairplot(df[["singleScore", "multiScore", "cores", "threads", "baseClock", "turboClock"]])

# %%
# headmap for correlation_matrix
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >
